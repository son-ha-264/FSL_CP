# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_proto_auroc_cp = pd.read_csv('../result_summary/protonet_cp_auroc_result_summary.csv')
df_multitask_auroc_cp = pd.read_csv('../result_summary/multitask_cp_auroc_result_summary.csv')
df_maml_auroc_cp = pd.read_csv('../result_summary/maml_cp_auroc_result_summary.csv')
df_singletask_auroc_cp = pd.read_csv('../result_summary/singletask_cp_auroc_result_summary.csv')
df_xgboost_auroc_cp = pd.read_csv('../result_summary/xgboost_cp_auroc_result_summary.csv')

df_logistic_auroc_cpplus = pd.read_csv('../result_summary/logistic_cp+_auroc_result_summary.csv')
df_protonet_auroc_cpplus = pd.read_csv('../result_summary/protonet_cp+_auroc_result_summary.csv')
df_maml_auroc_cpplus = pd.read_csv('../result_summary/maml_cp+_auroc_result_summary.csv')
df_xgboost_auroc_cpplus = pd.read_csv('../result_summary/xgboost_cp+_auroc_result_summary.csv')

df_proto_auroc_img = pd.read_csv('../result_summary/protonet_img_auroc_result_summary.csv')
df_maml_auroc_img = pd.read_csv('../result_summary/maml_img_auroc_result_summary.csv')

# %%
auroc_proto_img_8 = np.array([float(df_proto_auroc_img['8'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_img))])
auroc_proto_img_16 = np.array([float(df_proto_auroc_img['16'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_img))])
auroc_proto_img_32 = np.array([float(df_proto_auroc_img['32'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_img))])
auroc_proto_img_64 = np.array([float(df_proto_auroc_img['64'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_img))])
auroc_proto_img_96 = np.array([float(df_proto_auroc_img['96'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_img))])

auroc_maml_img_8 = np.array([float(df_maml_auroc_img['8'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_img))])
auroc_maml_img_16 = np.array([float(df_maml_auroc_img['16'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_img))])
auroc_maml_img_32 = np.array([float(df_maml_auroc_img['32'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_img))])
auroc_maml_img_64 = np.array([float(df_maml_auroc_img['64'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_img))])
auroc_maml_img_96 = np.array([float(df_maml_auroc_img['96'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_img))])

auroc_proto_cp_8 = np.array([float(df_proto_auroc_cp['8'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_cp))])
auroc_proto_cp_16 = np.array([float(df_proto_auroc_cp['16'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_cp))])
auroc_proto_cp_32 = np.array([float(df_proto_auroc_cp['32'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_cp))])
auroc_proto_cp_64 = np.array([float(df_proto_auroc_cp['64'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_cp))])
auroc_proto_cp_96 = np.array([float(df_proto_auroc_cp['96'][i].split('+/-')[0]) for i in range(len(df_proto_auroc_cp))])

auroc_maml_cp_8 = np.array([float(df_maml_auroc_cp['8'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cp))])
auroc_maml_cp_16 = np.array([float(df_maml_auroc_cp['16'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cp))])
auroc_maml_cp_32 = np.array([float(df_maml_auroc_cp['32'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cp))])
auroc_maml_cp_64 = np.array([float(df_maml_auroc_cp['64'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cp))])
auroc_maml_cp_96 = np.array([float(df_maml_auroc_cp['96'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cp))])

auroc_multitask_cp_8 = np.array([float(df_multitask_auroc_cp['8'][i].split('+/-')[0]) for i in range(len(df_multitask_auroc_cp))])
auroc_multitask_cp_16 = np.array([float(df_multitask_auroc_cp['16'][i].split('+/-')[0]) for i in range(len(df_multitask_auroc_cp))])
auroc_multitask_cp_32 = np.array([float(df_multitask_auroc_cp['32'][i].split('+/-')[0]) for i in range(len(df_multitask_auroc_cp))])
auroc_multitask_cp_64 = np.array([float(df_multitask_auroc_cp['64'][i].split('+/-')[0]) for i in range(len(df_multitask_auroc_cp))])
auroc_multitask_cp_96 = np.array([float(df_multitask_auroc_cp['96'][i].split('+/-')[0]) for i in range(len(df_multitask_auroc_cp))])

auroc_singletask_cp_8 = np.array([float(df_singletask_auroc_cp['8'][i].split('+/-')[0]) for i in range(len(df_singletask_auroc_cp))])
auroc_singletask_cp_16 = np.array([float(df_singletask_auroc_cp['16'][i].split('+/-')[0]) for i in range(len(df_singletask_auroc_cp))])
auroc_singletask_cp_32 = np.array([float(df_singletask_auroc_cp['32'][i].split('+/-')[0]) for i in range(len(df_singletask_auroc_cp))])
auroc_singletask_cp_64 = np.array([float(df_singletask_auroc_cp['64'][i].split('+/-')[0]) for i in range(len(df_singletask_auroc_cp))])
auroc_singletask_cp_96 = np.array([float(df_singletask_auroc_cp['96'][i].split('+/-')[0]) for i in range(len(df_singletask_auroc_cp))])

auroc_xgboost_cp_8 = np.array([float(df_xgboost_auroc_cp['8'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cp))])
auroc_xgboost_cp_16 = np.array([float(df_xgboost_auroc_cp['16'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cp))])
auroc_xgboost_cp_32 = np.array([float(df_xgboost_auroc_cp['32'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cp))])
auroc_xgboost_cp_64 = np.array([float(df_xgboost_auroc_cp['64'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cp))])
auroc_xgboost_cp_96 = np.array([float(df_xgboost_auroc_cp['96'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cp))])

auroc_xgboost_cpplus_8 = np.array([float(df_xgboost_auroc_cpplus['8'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cpplus))])
auroc_xgboost_cpplus_16 = np.array([float(df_xgboost_auroc_cpplus['16'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cpplus))])
auroc_xgboost_cpplus_32 = np.array([float(df_xgboost_auroc_cpplus['32'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cpplus))])
auroc_xgboost_cpplus_64 = np.array([float(df_xgboost_auroc_cpplus['64'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cpplus))])
auroc_xgboost_cpplus_96 = np.array([float(df_xgboost_auroc_cpplus['96'][i].split('+/-')[0]) for i in range(len(df_xgboost_auroc_cpplus))])

auroc_logistic_cpplus_8 = np.array([float(df_logistic_auroc_cpplus['8'][i].split('+/-')[0]) for i in range(len(df_logistic_auroc_cpplus))])
auroc_logistic_cpplus_16 = np.array([float(df_logistic_auroc_cpplus['16'][i].split('+/-')[0]) for i in range(len(df_logistic_auroc_cpplus))])
auroc_logistic_cpplus_32 = np.array([float(df_logistic_auroc_cpplus['32'][i].split('+/-')[0]) for i in range(len(df_logistic_auroc_cpplus))])
auroc_logistic_cpplus_64 = np.array([float(df_logistic_auroc_cpplus['64'][i].split('+/-')[0]) for i in range(len(df_logistic_auroc_cpplus))])
auroc_logistic_cpplus_96 = np.array([float(df_logistic_auroc_cpplus['96'][i].split('+/-')[0]) for i in range(len(df_logistic_auroc_cpplus))])

auroc_protonet_cpplus_8 = np.array([float(df_protonet_auroc_cpplus['8'][i].split('+/-')[0]) for i in range(len(df_protonet_auroc_cpplus))])
auroc_protonet_cpplus_16 = np.array([float(df_protonet_auroc_cpplus['16'][i].split('+/-')[0]) for i in range(len(df_protonet_auroc_cpplus))])
auroc_protonet_cpplus_32 = np.array([float(df_protonet_auroc_cpplus['32'][i].split('+/-')[0]) for i in range(len(df_protonet_auroc_cpplus))])
auroc_protonet_cpplus_64 = np.array([float(df_protonet_auroc_cpplus['64'][i].split('+/-')[0]) for i in range(len(df_protonet_auroc_cpplus))])
auroc_protonet_cpplus_96 = np.array([float(df_protonet_auroc_cpplus['96'][i].split('+/-')[0]) for i in range(len(df_protonet_auroc_cpplus))])

auroc_maml_cpplus_8 = np.array([float(df_maml_auroc_cpplus['8'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cpplus))])
auroc_maml_cpplus_16 = np.array([float(df_maml_auroc_cpplus['16'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cpplus))])
auroc_maml_cpplus_32 = np.array([float(df_maml_auroc_cpplus['32'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cpplus))])
auroc_maml_cpplus_64 = np.array([float(df_maml_auroc_cpplus['64'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cpplus))])
auroc_maml_cpplus_96 = np.array([float(df_maml_auroc_cpplus['96'][i].split('+/-')[0]) for i in range(len(df_maml_auroc_cpplus))])

# %%
# Avg score of each method for each assay
avg_proto_cp = np.mean([auroc_proto_cp_8,auroc_proto_cp_16, auroc_proto_cp_32, auroc_proto_cp_64, auroc_proto_cp_96], axis=0)
avg_proto_img = np.mean([auroc_proto_img_8, auroc_proto_img_16, auroc_proto_img_32, auroc_proto_img_64, auroc_proto_img_96], axis=0)
avg_multitask_cp = np.mean([auroc_multitask_cp_8, auroc_multitask_cp_16, auroc_multitask_cp_32, auroc_multitask_cp_64, auroc_multitask_cp_96], axis=0)
avg_maml_cp = np.mean([auroc_maml_cp_8, auroc_maml_cp_16, auroc_maml_cp_32, auroc_maml_cp_64, auroc_maml_cp_96], axis=0)
avg_xgboost_cpplus = np.mean([auroc_xgboost_cpplus_8, auroc_xgboost_cpplus_16, auroc_xgboost_cpplus_32, auroc_xgboost_cpplus_64, auroc_xgboost_cpplus_96], axis=0)
avg_maml_img = np.mean([auroc_maml_img_8, auroc_maml_img_16, auroc_maml_img_32, auroc_maml_img_64, auroc_maml_img_96], axis=0)
avg_singletask_cp = np.mean([auroc_singletask_cp_8, auroc_singletask_cp_16, auroc_singletask_cp_32, auroc_singletask_cp_64, auroc_singletask_cp_96], axis=0)
avg_maml_cpplus = np.mean([auroc_maml_cpplus_8, auroc_maml_cpplus_16, auroc_maml_cpplus_32, auroc_maml_cpplus_64, auroc_maml_cpplus_96], axis=0)
avg_protonet_cpplus = np.mean([auroc_protonet_cpplus_8, auroc_protonet_cpplus_16, auroc_protonet_cpplus_32, auroc_protonet_cpplus_64, auroc_protonet_cpplus_96], axis=0)
avg_logistic_cpplus = np.mean([auroc_logistic_cpplus_8, auroc_logistic_cpplus_16, auroc_logistic_cpplus_32, auroc_logistic_cpplus_64, auroc_logistic_cpplus_96], axis=0)
labels = list(df_proto_auroc_cp['assay_chembl_id'])

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    x = np.arange(len(labels))  # the label locations
    width = 0.15  # the width of the bars

    fig, ax = plt.subplots()
    fig.set_size_inches(15, 6)
    #rects1 = ax.bar(x - width, avg_maml_cp, width, label='maml')
    rects1 = ax.bar(x-width, avg_protonet_cpplus, width, label='protonet_cp+')
    rects3 = ax.bar(x, avg_multitask_cp, width, label='multitask_cp')
    rects2 = ax.bar(x + width, avg_proto_img, width, label='protonet_img')
    #rects3 = ax.bar(x, avg_maml_cpplus, width, label='maml_cp+')
    rects6 = ax.bar(x + 2*width, avg_logistic_cpplus, width, label='logistic_cp+')
    
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('AUC')
    ax.set_title('Mean AUC of unseen assay (Selected models)')
    ax.set_xticks(x, labels)
    ax.legend(loc='upper left')

    #ax.bar_label(rects1, padding=3)
    #ax.bar_label(rects2, padding=3)

    fig.tight_layout()

    plt.tick_params(axis='x', labelrotation=90)

    plt.ylim([0.45, 0.85])
    plt.savefig("../plots/Model_comparison_barplot1.png", bbox_inches='tight')
    plt.show()

# %%
# Best performing:
### CHEMBL3562136: PubChem BioAssay. qHTS Assay for Identifying Compounds that block Entry of Ebola Virus, Screen 2 blue channel. 
### CHEMBL2114807: PubChem BioAssay. qHTS Assay to Identify Small Molecule Activators of BRCA1 Expression.
### CHEMBL2114784: PubChem BioAssay. qHTS for Inhibitors of ATXN expression.
### CHEMBL1964081: PUBCHEM_BIOASSAY: S16 Schwann cell PMP22 intronic element firefly luciferase assay.
### CHEMBL1794584: PUBCHEM_BIOASSAY: qHTS for Inhibitors of TGF-b
### CHEMBL1794311: PUBCHEM_BIOASSAY: Inhibitors of the vitamin D receptor (VDR): qHTS. (Class of assay: confirmatory) [Related pubchem assays (depositor defined):AID504855]

# %%
avg_protonet_cp = [np.mean(auroc_proto_cp_8), np.mean(auroc_proto_cp_16), np.mean(auroc_proto_cp_32), np.mean(auroc_proto_cp_64), np.mean(auroc_proto_cp_96)]
avg_protonet_img = [np.mean(auroc_proto_img_8), np.mean(auroc_proto_img_16), np.mean(auroc_proto_img_32), np.mean(auroc_proto_img_64), np.mean(auroc_proto_img_96)]
avg_multitask_cp = [np.mean(auroc_multitask_cp_8), np.mean(auroc_multitask_cp_16), np.mean(auroc_multitask_cp_32), np.mean(auroc_multitask_cp_64), np.mean(auroc_multitask_cp_96)]
avg_maml_cp = [np.mean(auroc_maml_cp_8), np.mean(auroc_maml_cp_16), np.mean(auroc_maml_cp_32), np.mean(auroc_maml_cp_64), np.mean(auroc_maml_cp_96)]
avg_xgboost_cpplus = [np.mean(auroc_xgboost_cpplus_8), np.mean(auroc_xgboost_cpplus_16), np.mean(auroc_xgboost_cpplus_32), np.mean(auroc_xgboost_cpplus_64), np.mean(auroc_xgboost_cpplus_96)]
avg_maml_img = [np.mean(auroc_maml_img_8), np.mean(auroc_maml_img_16), np.mean(auroc_maml_img_32), np.mean(auroc_maml_img_64), np.mean(auroc_maml_img_96)]
avg_singletask_cp = [np.mean(auroc_singletask_cp_8), np.mean(auroc_singletask_cp_16), np.mean(auroc_singletask_cp_32), np.mean(auroc_singletask_cp_64), np.mean(auroc_singletask_cp_96)]
avg_logistic_cpplus = [np.mean(auroc_logistic_cpplus_8), np.mean(auroc_logistic_cpplus_16), np.mean(auroc_logistic_cpplus_32), np.mean(auroc_logistic_cpplus_64), np.mean(auroc_logistic_cpplus_96)]
avg_protonet_cpplus = [np.mean(auroc_protonet_cpplus_8), np.mean(auroc_protonet_cpplus_16), np.mean(auroc_protonet_cpplus_32), np.mean(auroc_protonet_cpplus_64), np.mean(auroc_protonet_cpplus_96)]
avg_maml_cpplus = [np.mean(auroc_maml_cpplus_8), np.mean(auroc_maml_cpplus_16), np.mean(auroc_maml_cpplus_32), np.mean(auroc_maml_cpplus_64), np.mean(auroc_maml_cpplus_96)]
avg_xgboost_cp = [np.mean(auroc_xgboost_cp_8), np.mean(auroc_xgboost_cp_16), np.mean(auroc_xgboost_cp_32), np.mean(auroc_xgboost_cp_64), np.mean(auroc_xgboost_cp_96)]

labels = ['8', '16', '32', '64', '96']

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    plt.errorbar(labels, avg_multitask_cp, yerr=np.std(avg_multitask_cp), color='orange', label='multitask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_img, yerr=np.std(avg_protonet_img), color='teal', linestyle='dashed', label='protonet_img', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_cpplus, yerr=np.std(avg_maml_cp), color='blue', label='maml_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_logistic_cpplus, yerr=np.std(avg_logistic_cpplus), color='green', label='logistic_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_img, yerr=np.std(avg_maml_img), color='blue', label='maml_img', marker='o', linestyle='dashed', linewidth=0.5)
    plt.errorbar(labels, avg_singletask_cp, yerr=np.std(avg_singletask_cp), color='purple', label='singletask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cpplus, yerr=np.std(avg_protonet_cpplus), color='red', label='protonet_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cp, yerr=np.std(avg_protonet_cp), color='teal', label='protonet_cp', marker='o', linewidth=0.5)
    #plt.errorbar(labels, avg_xgboost_cpplus, yerr=np.std(avg_xgboost_cpplus), color='black', label='xgboost_cp+', marker='o', linewidth=0.5)
    #plt.errorbar(labels, avg_xgboost_cp, yerr=np.std(avg_xgboost_cp), color='brown', label='xgboost_cp', marker='o', linewidth=0.5)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    plt.ylabel('AUC')
    plt.xlabel('Support set size')
    plt.suptitle('Mean AUC on unseen assays as support set size increases')
    #plt.xticks([])
    plt.legend(loc='upper left')

    #ax.bar_label(rects1, padding=3)
    #ax.bar_label(rects2, padding=3)

    fig.tight_layout()

    plt.tick_params(axis='x', labelrotation=90)

    plt.ylim([0.51, 0.72])
    plt.savefig("../plots/Model_comparison_lineplot1.png")
    plt.show()

# %%
data = [auroc_protonet_cpplus_64, auroc_proto_cp_64, auroc_multitask_cp_64, auroc_singletask_cp_64, auroc_maml_cpplus_64, auroc_logistic_cpplus_64, auroc_maml_img_64, auroc_proto_img_64]

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    plt.boxplot(data)
    plt.ylabel('AUC')
    plt.suptitle('AUC scores on unseen assays, support_size=64')
    plt.tick_params(axis='x', labelrotation=90)
    #plt.xticks([1,2,3,4], ['multitask_cp+', 'protonet_cp+', 'protonet_img', 'cloome_img'])
    plt.xticks([1,2,3,4,5,6,7,8], ['protonet_cp+', 'protonet_cp', 'multitask_cp', 'singletask_cp', 'maml_cp+', 'logistic_cp+', 'maml_img', 'protonet_img'])
    plt.savefig("../plots/Model_comparison_boxplot1.png",  bbox_inches='tight')
    plt.show()

# %% [markdown]
# Below are highlights of some models.

# %%
# Highlight the best model is protonet_cp+, and vs protonet_cp

labels = ['8', '16', '32', '64', '96']

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    plt.errorbar(labels, avg_multitask_cp, yerr=np.std(avg_multitask_cp), color='gray', label='multitask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_img, yerr=np.std(avg_protonet_img), color='gray', linestyle='dashed', label='protonet_img', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_cpplus, yerr=np.std(avg_maml_cp), color='gray', label='maml_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_logistic_cpplus, yerr=np.std(avg_logistic_cpplus), color='gray', label='logistic_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_img, yerr=np.std(avg_maml_img), color='gray', label='maml_img', marker='o', linestyle='dashed', linewidth=0.5)
    plt.errorbar(labels, avg_singletask_cp, yerr=np.std(avg_singletask_cp), color='gray', label='singletask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cpplus, yerr=np.std(avg_protonet_cpplus), color='red', label='protonet_cp+', marker='o', linewidth=1)
    plt.errorbar(labels, avg_protonet_cp, yerr=np.std(avg_protonet_cp), color='teal', label='protonet_cp', marker='o', linewidth=1)
    #plt.errorbar(labels, avg_xgboost_cpplus, yerr=np.std(avg_xgboost_cpplus), color='black', label='xgboost_cp+', marker='o', linewidth=0.5)
    #plt.errorbar(labels, avg_xgboost_cp, yerr=np.std(avg_xgboost_cp), color='brown', label='xgboost_cp', marker='o', linewidth=0.5)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    plt.ylabel('AUC')
    plt.xlabel('Support set size')
    plt.suptitle('Mean AUC on unseen assays as support set size increases')
    #plt.xticks([])
    plt.legend(loc='upper left')

    #ax.bar_label(rects1, padding=3)
    #ax.bar_label(rects2, padding=3)

    fig.tight_layout()

    plt.tick_params(axis='x', labelrotation=90)

    plt.ylim([0.51, 0.72])
    plt.savefig("../plots/Model_comparison_lineplot2.png")
    plt.show()

# %%
# multitask, pretraning vs non-pretraining

labels = ['8', '16', '32', '64', '96']

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    plt.errorbar(labels, avg_multitask_cp, yerr=np.std(avg_multitask_cp), color='orange', label='multitask_cp', marker='o', linewidth=1)
    plt.errorbar(labels, avg_protonet_img, yerr=np.std(avg_protonet_img), color='gray', linestyle='dashed', label='protonet_img', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_cpplus, yerr=np.std(avg_maml_cp), color='gray', label='maml_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_logistic_cpplus, yerr=np.std(avg_logistic_cpplus), color='gray', label='logistic_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_img, yerr=np.std(avg_maml_img), color='gray', label='maml_img', marker='o', linestyle='dashed', linewidth=0.5)
    plt.errorbar(labels, avg_singletask_cp, yerr=np.std(avg_singletask_cp), color='purple', label='singletask_cp', marker='o', linewidth=1)
    plt.errorbar(labels, avg_protonet_cpplus, yerr=np.std(avg_protonet_cpplus), color='gray', label='protonet_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cp, yerr=np.std(avg_protonet_cp), color='gray', label='protonet_cp', marker='o', linewidth=0.5)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    plt.ylabel('AUC')
    plt.xlabel('Support set size')
    plt.suptitle('Mean AUC on unseen assays as support set size increases')
    #plt.xticks([])
    plt.legend(loc='upper left')

    #ax.bar_label(rects1, padding=3)
    #ax.bar_label(rects2, padding=3)

    fig.tight_layout()

    plt.tick_params(axis='x', labelrotation=90)

    plt.ylim([0.51, 0.72])
    plt.savefig("../plots/Model_comparison_lineplot3.png")
    plt.show()

# %%
# pure CNN underperforms

labels = ['8', '16', '32', '64', '96']

with plt.style.context(['seaborn-v0_8-deep', 'seaborn']):
    plt.errorbar(labels, avg_multitask_cp, yerr=np.std(avg_multitask_cp), color='gray', label='multitask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_img, yerr=np.std(avg_protonet_img), color='teal', linestyle='dashed', label='protonet_img', marker='o', linewidth=1)
    plt.errorbar(labels, avg_maml_cpplus, yerr=np.std(avg_maml_cp), color='gray', label='maml_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_logistic_cpplus, yerr=np.std(avg_logistic_cpplus), color='gray', label='logistic_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_maml_img, yerr=np.std(avg_maml_img), color='blue', label='maml_img', marker='o', linestyle='dashed', linewidth=1)
    plt.errorbar(labels, avg_singletask_cp, yerr=np.std(avg_singletask_cp), color='gray', label='singletask_cp', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cpplus, yerr=np.std(avg_protonet_cpplus), color='gray', label='protonet_cp+', marker='o', linewidth=0.5)
    plt.errorbar(labels, avg_protonet_cp, yerr=np.std(avg_protonet_cp), color='gray', label='protonet_cp', marker='o', linewidth=0.5)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    plt.ylabel('AUC')
    plt.xlabel('Support set size')
    plt.suptitle('Mean AUC on unseen assays as support set size increases')
    #plt.xticks([])
    plt.legend(loc='upper left')

    #ax.bar_label(rects1, padding=3)
    #ax.bar_label(rects2, padding=3)

    fig.tight_layout()

    plt.tick_params(axis='x', labelrotation=90)

    plt.ylim([0.51, 0.72])
    plt.savefig("../plots/Model_comparison_lineplot4.png")
    plt.show()
